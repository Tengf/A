# %% [markdown]
# # HW_assignment1
# ### distributions: chisquare, normal, poisson, binomial, geometric, exponential

# %%
from __future__ import print_function
__author__= 'tz'
import os

from scipy.optimize import curve_fit, minimize
import numpy as np
import pylab as pl

# %%
mymean=100
df = 100
md={}
distributions = ['chisq', 'gaus', 'pois', 'binomial', 'geometric', 'exponential']
mysize=1000/(np.array(range(1,100)+[10]))
means = {}
allmeans=[]

# %%
md['chisq'] = np.random.chisquare(df, size=100)
md['gaus'] = np.random.normal(df, 100, size=100)
md['pois'] = np.random.poisson(df, size=100)
md['binomial'] = np.random.binomial(200, 0.5, size=n)
md['geometric'] = np.random.geometric(0.01, size=100)
md['exponential'] = np.random.exponential(df, size=100)

# %%
np.random.seed(1)
md['chisq']={} 
for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size=n)
    
means['chisq'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['chisq'].iterkeys():
    means['chisq'][nn] = md['chisq'][nn].mean()
    axchisq_mu_n.plot(nn, means['chisq'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[df,df], 'k')

# %%
np.random.seed(1)
md['gaus']={} 
for n in mysize:
    md['gaus'][n] = np.random.normal(df, 100, size=n)
    
means['gaus'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['gaus'].iterkeys():
    means['gaus'][nn] = md['gaus'][nn].mean()
    axchisq_mu_n.plot(nn, means['gaus'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[df,df], 'k')

# %%
np.random.seed(1)
md['pois']={} 
for n in mysize:
    md['pois'][n] = np.random.poisson(df, size=n)
    
means['pois'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['pois'].iterkeys():
    means['pois'][nn] = md['pois'][nn].mean()
    axchisq_mu_n.plot(nn, means['pois'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[df,df], 'k')

# %%
np.random.seed(1)
md['binomial']={} 
for n in mysize:
    md['binomial'][n] = np.random.binomial(200, 0.5, size=n)
    
means['binomial'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['binomial'].iterkeys():
    means['binomial'][nn] = md['binomial'][nn].mean()
    axchisq_mu_n.plot(nn, means['binomial'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[df,df], 'k')

# %%
np.random.seed(1)
md['geometric']={} 
for n in mysize:
    md['geometric'][n] = np.random.geometric(0.01, size=100)
    
means['geometric'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['geometric'].iterkeys():
    means['geometric'][nn] = md['geometric'][nn].mean()
    axchisq_mu_n.plot(nn, means['geometric'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[df,df], 'k')

# %%
np.random.seed(1)
md['exponential']={} 
for n in mysize:
    md['exponential'][n] = np.random.exponential(df, size=100)
    
means['exponential'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['exponential'].iterkeys():
    means['exponential'][nn] = md['exponential'][nn].mean()
    axchisq_mu_n.plot(nn, means['exponential'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[df,df], 'k')

# %% [markdown]
# ### The sample mean comes near to population mean ,when sample size is bigger. They look as I expected.

# %% [markdown]
# # PLOT the distributions of all sample means

# %% [markdown]
# ### the chisquare distribution of sample means

# %%
from scipy.stats import norm as nm
import matplotlib.mlab as mlab
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
allmeans=[]
for n in means['chisq']:
    allmeans.append(means['chisq'][n])
pl.figure(figsize=(10,10))
(mu, sigma) = nm.fit(allmeans)
plt.hist(allmeans, normed=1, bins = 30)
xx = linspace(90,110,100)
y = mlab.normpdf( xx, mu, sigma)
l = pl.plot(xx, y, 'r--', linewidth=2)
#pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %% [markdown]
# ### the normal distribution of sample means

# %%
allmeans=[]
for n in means['gaus']:
    allmeans.append(means['gaus'][n])
pl.figure(figsize=(10,10))
(mu, sigma) = nm.fit(allmeans)
plt.hist(allmeans, normed=1, bins = 30)
xx = linspace(50,150,100)
y = mlab.normpdf( xx, mu, sigma)
l = pl.plot(xx, y, 'r--', linewidth=2)
#pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %% [markdown]
# ### the poisson distribution of sample means

# %%
allmeans=[]
for n in means['pois']:
    allmeans.append(means['pois'][n])
pl.figure(figsize=(10,10))
(mu, sigma) = nm.fit(allmeans)
plt.hist(allmeans, normed=1, bins = 30)
xx = linspace(90,110,100)
y = mlab.normpdf( xx, mu, sigma)
l = pl.plot(xx, y, 'r--', linewidth=2)
#pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %% [markdown]
# ### binomial distribution of sample means

# %%
allmeans=[]
for n in means['binomial']:
    allmeans.append(means['binomial'][n])
pl.figure(figsize=(10,10))
(mu, sigma) = nm.fit(allmeans)
plt.hist(allmeans, normed=1, bins = 30)
xx = linspace(90,110,100)
y = mlab.normpdf( xx, mu, sigma)
l = pl.plot(xx, y, 'r--', linewidth=2)
#pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %% [markdown]
# ### geometric distribution of sample means

# %%
allmeans=[]
for n in means['geometric']:
    allmeans.append(means['geometric'][n])
pl.figure(figsize=(10,10))
(mu, sigma) = nm.fit(allmeans)
plt.hist(allmeans, normed=1, bins = 30)
xx = linspace(50,150,100)
y = mlab.normpdf( xx, mu, sigma)
l = pl.plot(xx, y, 'r--', linewidth=2)
#pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %% [markdown]
# ### exponential distribution of sample means

# %%
allmeans=[]
for n in means['exponential']:
    allmeans.append(means['exponential'][n])
pl.figure(figsize=(10,10))
(mu, sigma) = nm.fit(allmeans)
plt.hist(allmeans, normed=1, bins = 30)
xx = linspace(70,130,100)
y = mlab.normpdf( xx, mu, sigma)
l = pl.plot(xx, y, 'r--', linewidth=2)
#pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %% [markdown]
# ## PLOT the distributions of all sample means (together for all distributions)

# %%
allmeans=[]
for n in means['chisq']:
    allmeans.append(means['chisq'][n])
for n in means['gaus']:
    allmeans.append(means['gaus'][n])
for n in means['pois']:
    allmeans.append(means['pois'][n])
for n in means['binomial']:
    allmeans.append(means['binomial'][n])
for n in means['geometric']:
    allmeans.append(means['geometric'][n])
for n in means['exponential']:
    allmeans.append(means['exponential'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
from scipy.stats import norm
import matplotlib.mlab as mlab

(mu, sigma) = norm.fit(allmeans)
pl.figure(figsize=(10,10))
n, bins, patches = plt.hist(allmeans, normed=1, bins = 30,  facecolor='blue', alpha=0.5)
y = mlab.normpdf( bins, mu, sigma)
l = pl.plot(bins, y, 'r--', linewidth=2)
